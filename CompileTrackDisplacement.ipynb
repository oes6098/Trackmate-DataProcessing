# %%
#Make sure pandas is installed
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.1-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting numpy<2,>=1.23.2 (from pandas)
#   Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------------------------- ------------ 41.0/61.0 kB 991.0 kB/s eta 0:00:01
#      ---------------------------------------- 61.0/61.0 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\oes6098\documents\github\trackmate-data-processing\.conda\lib\site-packages (from pandas) (2.9.0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\oes6098\documents\github\trackmate-data-processing\.conda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.1-cp311-cp311-win_amd64.whl (11.6 MB)
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.6/11.6 MB 18.8 MB/s eta 0:00:01
#    ------------ --------------------------- 3.7/11.6 MB 47.5 MB/s eta 0:00:01
#    ------------------------ --------------- 7.2/11.6 MB 65.9 MB/s eta 0:00:01
#    -------------------------- ------------- 7.6/11.6 MB 43.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.5/11.6 MB 38.8 MB/s eta 0:00:01
#    --------------------------------- ------ 9.7/11.6 MB 36.6 MB/s eta 0:00:01
#    -------------------------------------- - 11.3/11.6 MB 40.9 MB/s eta 0:00:01
#    ---------------------------------------  11.6/11.6 MB 36.3 MB/s eta 0:00:01
#    ---------------------------------------  11.6/11.6 MB 36.3 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 27.3 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    ------ --------------------------------- 2.6/15.8 MB 82.3 MB/s eta 0:00:01
#    -------- ------------------------------- 3.5/15.8 MB 45.0 MB/s eta 0:00:01
#    ------------ --------------------------- 4.8/15.8 MB 38.6 MB/s eta 0:00:01
#    -------------------- ------------------- 8.2/15.8 MB 47.3 MB/s eta 0:00:01
#    --------------------------------- ------ 13.2/15.8 MB 65.2 MB/s eta 0:00:01
#    ---------------------------------------  15.8/15.8 MB 110.0 MB/s eta 0:00:01
#    ---------------------------------------  15.8/15.8 MB 110.0 MB/s eta 0:00:01
#    ---------------------------------------- 15.8/15.8 MB 50.3 MB/s eta 0:00:00
# Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#    ---------------------------------------- 0.0/505.5 kB ? eta -:--:--
#    --------------------------------------- 505.5/505.5 kB 31.0 MB/s eta 0:00:00
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ---------------------------------------- 0.0/345.4 kB ? eta -:--:--
#    --------------------------------------- 345.4/345.4 kB 10.8 MB/s eta 0:00:00
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-1.26.4 pandas-2.2.1 pytz-2024.1 tzdata-2024.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Batch Extract and Compile Track Displacement Data

# %% [markdown]
# # Filter out tracks less than 10sec duration

# %%
import os
import pandas as pd
import numpy as np
from tkinter import filedialog
import tkinter as tk

# Create a Tkinter root window
root = tk.Tk()
root.withdraw()  # Hide the root window

# Ask user to select the input directory using a file dialog
input_directory = filedialog.askdirectory(title="Select Input Directory")

# Check if a directory was selected
if not input_directory:
    print("No directory selected. Exiting...")
    exit()

# Create a list to store NumPy arrays
result_arrays = []

# Iterate over folders in the directory
for folder_name in os.listdir(input_directory):
    folder_path = os.path.join(input_directory, folder_name)
    
    # Check if the item in the directory is a folder
    if os.path.isdir(folder_path):
        print('file exists')
        # Check if export.csv exists in the folder
        export_csv_path = os.path.join(folder_path, 'export.csv')
        if not os.path.exists(export_csv_path):
            print(f"export.csv not found in folder '{folder_name}'. Skipping...")
            continue
        
        # Read the CSV file into a pandas DataFrame
        df = pd.read_csv(export_csv_path)

        # Convert 'TRACK_DISPLACEMENT' and 'TRACK_DURATION' to numeric values
        df['TRACK_DISPLACEMENT'] = pd.to_numeric(df['TRACK_DISPLACEMENT'], errors='coerce')
        df['TRACK_DURATION'] = pd.to_numeric(df['TRACK_DURATION'], errors='coerce')

        # Filter rows starting from the 5th row based on conditions
        filtered_rows = df.iloc[4:].loc[(~df['TRACK_DISPLACEMENT'].isna()) & (df['TRACK_DURATION'] >= 10)]

        # Extract values from column 'TRACK_MEAN_SPEED' and convert them to a NumPy array
        result_array = np.array(filtered_rows['TRACK_DISPLACEMENT'])

        # Add the NumPy array to the list
        result_arrays.append(result_array)

if result_arrays:
    # Create a DataFrame from the list of arrays
    result_df = pd.DataFrame(result_arrays).T
    result_df.columns = [f'Column_{i+1}' for i in range(result_df.shape[1])]

    # Save the resulting DataFrame to a CSV file
    result_df.to_csv(os.path.join(input_directory, 'trackdisplacement10sec.csv'), index=False)
    print("Results saved successfully.")
else:
    print("No valid data found to save.")
# Out:
# file exists
# file exists
# file exists
# file exists
# file exists
# Results saved successfully.

# %% [markdown]
# # Filter out tracks less than 10sec duration

# %%
import os
import pandas as pd
import numpy as np
from tkinter import filedialog
import tkinter as tk

# Create a Tkinter root window
root = tk.Tk()
root.withdraw()  # Hide the root window

# Ask user to select the input directory using a file dialog
input_directory = filedialog.askdirectory(title="Select Input Directory")

# Check if a directory was selected
if not input_directory:
    print("No directory selected. Exiting...")
    exit()

# Create a list to store NumPy arrays
result_arrays = []

# Iterate over folders in the directory
for folder_name in os.listdir(input_directory):
    folder_path = os.path.join(input_directory, folder_name)
    
    # Check if the item in the directory is a folder
    if os.path.isdir(folder_path):
        print('file exists')
        # Check if export.csv exists in the folder
        export_csv_path = os.path.join(folder_path, 'export.csv')
        if not os.path.exists(export_csv_path):
            print(f"export.csv not found in folder '{folder_name}'. Skipping...")
            continue
        
        # Read the CSV file into a pandas DataFrame
        df = pd.read_csv(export_csv_path)

        # Convert 'TRACK_DISPLACEMENT' and 'TRACK_DURATION' to numeric values
        df['TRACK_DISPLACEMENT'] = pd.to_numeric(df['TRACK_DISPLACEMENT'], errors='coerce')
        df['TRACK_DURATION'] = pd.to_numeric(df['TRACK_DURATION'], errors='coerce')

        # Filter rows starting from the 5th row based on conditions
        filtered_rows = df.iloc[4:].loc[(~df['TRACK_DISPLACEMENT'].isna()) & (df['TRACK_DURATION'] >= 20)]

        # Extract values from column 'TRACK_MEAN_SPEED' and convert them to a NumPy array
        result_array = np.array(filtered_rows['TRACK_DISPLACEMENT'])

        # Add the NumPy array to the list
        result_arrays.append(result_array)

if result_arrays:
    # Create a DataFrame from the list of arrays
    result_df = pd.DataFrame(result_arrays).T
    result_df.columns = [f'Column_{i+1}' for i in range(result_df.shape[1])]

    # Save the resulting DataFrame to a CSV file
    result_df.to_csv(os.path.join(input_directory, 'trackdisplacement20sec.csv'), index=False)
    print("Results saved successfully.")
else:
    print("No valid data found to save.")
